# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
import random

# %%
df = pd.read_csv ("lyrics.csv", sep = '|')

# %%
#df.describe

# %%
shuffled = df.sample(frac=1)
result = np.array_split(shuffled, 4845)

# %%
#result[1]

# %%
master_playlist_array = np.empty(0, dtype=object, order="C")

# %%
for x in range(2):
    for part in result[x]:
        for track in part:
            master_playlist_array = np.append(master_playlist_array, {"playlist":f"playlist {x}", "track_uri": track})

# %%
master_playlist_array
# Out:
# array([{'playlist': 'playlist 0', 'track_uri': 'a'},
#        {'playlist': 'playlist 0', 'track_uri': 'r'},
#        {'playlist': 'playlist 0', 'track_uri': 't'},
#        {'playlist': 'playlist 0', 'track_uri': 'i'},
#        {'playlist': 'playlist 0', 'track_uri': 's'},
#        {'playlist': 'playlist 0', 'track_uri': 't'},
#        {'playlist': 'playlist 0', 'track_uri': '_'},
#        {'playlist': 'playlist 0', 'track_uri': 'u'},
#        {'playlist': 'playlist 0', 'track_uri': 'r'},
#        {'playlist': 'playlist 0', 'track_uri': 'i'},
#        {'playlist': 'playlist 0', 'track_uri': 'a'},
#        {'playlist': 'playlist 0', 'track_uri': 'r'},
#        {'playlist': 'playlist 0', 'track_uri': 't'},
#        {'playlist': 'playlist 0', 'track_uri': 'i'},
#        {'playlist': 'playlist 0', 'track_uri': 's'},
#        {'playlist': 'playlist 0', 'track_uri': 't'},
#        {'playlist': 'playlist 0', 'track_uri': '_'},
#        {'playlist': 'playlist 0', 'track_uri': 'n'},
# ...

# %%
np.random.choice(df_playlist['track_uri'], 6000)
# Out:
# array(['12cvvbfORyRP9E9Bk6PGbG', '1gB1A2Qcgo5RYnQujS3bCd',
#        '07M7PmWvTlk7iap9zsfHB2', ..., '2IGV86yleBgcU2F2iVBFed',
#        '278jo4sRAoXzydLTzXtgE2', '7ldCklGtxrVxpmdt1el897'], dtype=object)

# %%
N = 6000

# %%
split(df_playlist, sample(1:N, nrow(df_playlist), replace=T))
# Out:
#   File "<ipython-input-35-b6ab7934b928>", line 1
#     split(df_playlist, sample(1:N, nrow(df_playlist), replace=T))
#                                ^
# SyntaxError: invalid syntax

# %%
playlist_train = train_test_split(df_playlist)

# %%
playlist_train
# Out:
# [                     track_uri  acousticness  danceability  energy    tempo  \
#  219072  3I3LdO54esKe0bTIhKgAUb      0.204000         0.306  0.8380   82.953
#  13156   3fElZarkAyg20nEvULMiuY      0.004900         0.275  0.8330  141.729
#  136260  4lMB8kBRDG4vBiFEXG0nRE      0.536000         0.655  0.4780   88.229
#  13339   25ASkS4Hx8RrtyqrDScez3      0.005120         0.384  0.4210  113.633
#  177840  13LbS3CLWgEDv2FvgZiaMC      0.229000         0.521  0.6890   82.763
#  229649  2AM3v5RB6Xq42AKZYkRYCJ      0.924000         0.173  0.1740  181.134
#  152487  3yfVjCrDVoxs0Ui4SVtOLr      0.015200         0.528  0.9110  141.064
#  229413  4gvVgjymZQ7erv4OYQ0HjZ      0.001140         0.343  0.7600  155.140
#  177036  7q0AwChezqZqg0ywK6dFtZ      0.542000         0.645  0.7210   82.335
#  103715  2rNawLFXIfZ7A63OUE8hYO      0.286000         0.680  0.5100  131.983
#  32849   6bwQonliHssKE84W1FXoab      0.018100         0.518  0.7080  107.032
# ...

# %%
#df_playlist_train = pd.DataFrame(np.array(playlist_train).reshape(), columns = list(123456))

#np.array(my_list).reshape(57771,6), columns = list("abc"))

# %%
#random.sample(playlist_train, 20)

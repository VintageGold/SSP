# %%
import awscli
import pandas as pd
import boto3
from s3 import get_file,upload_file

# %%
s3 = boto3.resource('s3')

a = get_file(s3,bucket_name='s3ssp',download_file='Data/master_audio_features.csv',rename_file='new_upload.csv')

# %%
df = pd.read_csv(a,sep='|')
df.sample(50)
# Out:
#                     artist_uri      info_artist_name  Fuzzy Score  \
# 43384   6nwh8AhPpbwOUnHZJWrHT6       David Allan Coe           94
# 77383   7Coo58A8U3BCpCl4nQ3pda             Angelspit          100
# 41843   1MK9J20Op7jFgUDbLiy6m2       Danza Invisible          100
# 65220   5BnNG7QQQDTNd43ozx5y13     Blackmore's Night          100
# 43298   64tNsm6TnZe2zpcMVMOoHL       Alice In Chains           94
# 10925   3bhckpkRmz8mqONUceSutp       Gerald Albright          100
# 21356   2iM28IgKg89v1o7BTQAVPo         Bruce Hornsby          100
# 88569   0RNUFiiD25X0wWml4K44ni          Edison Glass          100
# 63015   6eUKZXaKkcviH0Ku9w2n3V            Ed Sheeran          100
# 57180   6J7rw7NELJUCThPbAfyLIE        The Civil Wars          100
# 68208   5DqmNLPM1kAbSBQk2FMm6b          Amanda Perez          100
# 100287  7tlQrRh6jNY1c95poJvBe9       Deitrick Haddon          100
# 124260  1caBfBEapzw8z2Qz9q0OaQ     Asking Alexandria           95
# ...

# %%
df.describe()
# Out:
#          Fuzzy Score   acousticness   danceability         energy  \
# count  133089.000000  133081.000000  133081.000000  133081.000000
# mean       99.071328       0.254829       0.507081       0.663843
# std         2.334765       0.314324       0.171204       0.249479
# min        90.000000       0.000000       0.000000       0.000000
# 25%       100.000000       0.004130       0.388000       0.483000
# 50%       100.000000       0.085600       0.512000       0.710000
# 75%       100.000000       0.462000       0.630000       0.882000
# max       100.000000       0.996000       0.985000       1.000000
#
#        instrumentalness            key       liveness       loudness  \
# count     133081.000000  133081.000000  133081.000000  133081.000000
# mean           0.123252       5.272443       0.243518      -8.189091
# std            0.264849       3.547703       0.221663       4.140703
# min            0.000000       0.000000       0.000000     -60.000000
# ...
